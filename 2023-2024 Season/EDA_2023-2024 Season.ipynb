# %%
# Import the EDA packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#Display Settings:
pd.set_option('display.max_columns', None) # Display Preference

# %%
# 2023-2024 BIOS:
data_BIOS_AS_23_24 = pd.read_csv('NHL Player Season BIOS - AS - 2023-2024.csv', index_col=0)
data_BIOS_ES_23_24 = pd.read_csv('NHL Player Season BIOS - ES - 2023-2024.csv', index_col=0)
data_BIOS_PP_23_24 = pd.read_csv('NHL Player Season BIOS - PP - 2023-2024.csv', index_col=0)
data_BIOS_PK_23_24 = pd.read_csv('NHL Player Season BIOS - PK - 2023-2024.csv', index_col=0)

# 2023-2024 Individual Season Totals
data_indiv_totals_AS_23_24 = pd.read_csv('NHL Player Individual Season Totals - AS - 2023-2024.csv', index_col=0)
data_indiv_totals_ES_23_24 = pd.read_csv('NHL Player Individual Season Totals - ES - 2023-2024.csv', index_col=0)
data_indiv_totals_PP_23_24 = pd.read_csv('NHL Player Individual Season Totals - PP - 2023-2024.csv', index_col=0)
data_indiv_totals_PK_23_24 = pd.read_csv('NHL Player Individual Season Totals - PK - 2023-2024.csv', index_col=0)

# 2023-2024 Individual Season Rates
data_indiv_rates_AS_23_24 = pd.read_csv('NHL Player Individual Season Rates - AS - 2023-2024.csv', index_col=0)
data_indiv_rates_ES_23_24 = pd.read_csv('NHL Player Individual Season Rates - ES - 2023-2024.csv', index_col=0)
data_indiv_rates_PP_23_24 = pd.read_csv('NHL Player Individual Season Rates - PP - 2023-2024.csv', index_col=0)
data_indiv_rates_PK_23_24 = pd.read_csv('NHL Player Individual Season Rates - PK - 2023-2024.csv', index_col=0)

# 2023-2024 On-Ice Stat Totals
data_on_ice_totals_AS_23_24 = pd.read_csv('NHL Player On-Ice Totals - AS - 2023-2024.csv', index_col=0)
data_on_ice_totals_ES_23_24 = pd.read_csv('NHL Player On-Ice Totals - ES - 2023-2024.csv', index_col=0)
data_on_ice_totals_PP_23_24 = pd.read_csv('NHL Player On-Ice Totals - PP - 2023-2024.csv', index_col=0)
data_on_ice_totals_PK_23_24 = pd.read_csv('NHL Player On-Ice Totals - PK - 2023-2024.csv', index_col=0)

# 2023-2024 On-Ice Stat Rates
data_on_ice_rates_AS_23_24 = pd.read_csv('NHL Player On-Ice Rates - AS - 2023-2024.csv', index_col=0)
data_on_ice_rates_ES_23_24 = pd.read_csv('NHL Player On-Ice Rates - ES - 2023-2024.csv', index_col=0)
data_on_ice_rates_PP_23_24 = pd.read_csv('NHL Player On-Ice Rates - PP - 2023-2024.csv', index_col=0)
data_on_ice_rates_PK_23_24 = pd.read_csv('NHL Player On-Ice Rates - PK - 2023-2024.csv', index_col=0)

# %%
# Updating the Data after the end of the season. Only one game left for 6 teams.
data_BIOS_AS_23_24_update = pd.read_csv('NHL Player Bios_AS_2024.csv', index_col=0)
data_BIOS_ES_23_24_update = pd.read_csv('NHL Player Bios_ES_2024.csv', index_col=0)
data_BIOS_PP_23_24_update = pd.read_csv('NHL Player Bios_PP_2024.csv', index_col=0)
data_BIOS_PK_23_24_update = pd.read_csv('NHL Player Bios_PP_2024.csv', index_col=0)

data_indiv_totals_AS_23_24_update = pd.read_csv('NHL Player Individual Total_AS_2024.csv', index_col=0)
data_indiv_totals_ES_23_24_update = pd.read_csv('NHL Player Individual Total_ES_2024.csv', index_col=0)
data_indiv_totals_PP_23_24_update = pd.read_csv('NHL Player Individual Total_PP_2024.csv', index_col=0)
data_indiv_totals_PK_23_24_update = pd.read_csv('NHL Player Individual Total_PK_2024.csv', index_col=0)

data_indiv_rates_AS_23_24_update = pd.read_csv('NHL Player Individual Rates_AS_2024.csv', index_col=0)
data_indiv_rates_ES_23_24_update = pd.read_csv('NHL Player Individual Rates_ES_2024.csv', index_col=0)
data_indiv_rates_PP_23_24_update = pd.read_csv('NHL Player Individual Rates_PP_2024.csv', index_col=0)
data_indiv_rates_PK_23_24_update = pd.read_csv('NHL Player Individual Rates_PK_2024.csv', index_col=0)

data_on_ice_totals_AS_23_24_update = pd.read_csv('NHL Player On-Ice Totals_AS_2024.csv', index_col=0)
data_on_ice_totals_ES_23_24_update = pd.read_csv('NHL Player On-Ice Totals_ES_2024.csv', index_col=0)
data_on_ice_totals_PP_23_24_update = pd.read_csv('NHL Player On-Ice Totals_PP_2024.csv', index_col=0)
data_on_ice_totals_PK_23_24_update = pd.read_csv('NHL Player On-Ice Totals_PK_2024.csv', index_col=0)

data_on_ice_rates_AS_23_24_update = pd.read_csv('NHL Player On-Ice Rates_AS_2024.csv', index_col=0)
data_on_ice_rates_ES_23_24_update = pd.read_csv('NHL Player On-Ice Rates_ES_2024.csv', index_col=0)
data_on_ice_rates_PP_23_24_update = pd.read_csv('NHL Player On-Ice Rates_PP_2024.csv', index_col=0)
data_on_ice_rates_PK_23_24_update = pd.read_csv('NHL Player On-Ice Rates_PK_2024.csv', index_col=0)

# %%
# LISTS OF THE DATAFRAMES:

# BIOS:
all_situations_bios_23_24 = [data_BIOS_AS_23_24,
                             data_BIOS_ES_23_24,
                             data_BIOS_PP_23_24,
                             data_BIOS_PK_23_24]

all_situations_bios_23_24_update = [data_BIOS_AS_23_24_update,
                                    data_BIOS_ES_23_24_update,
                                    data_BIOS_PP_23_24_update,
                                    data_BIOS_PK_23_24_update]

# INDIV SEASON TOTALS:
all_situations_indiv_totals_23_24 = [data_indiv_totals_AS_23_24,
                                     data_indiv_totals_ES_23_24,
                                     data_indiv_totals_PP_23_24,
                                     data_indiv_totals_PK_23_24,]

all_situations_indiv_totals_23_24_update = [data_indiv_totals_AS_23_24_update,
                                            data_indiv_totals_ES_23_24_update,
                                            data_indiv_totals_PP_23_24_update,
                                            data_indiv_totals_PK_23_24_update,]

# INDIV SEASON RATES:
all_situations_indiv_rates_23_24 = [data_indiv_rates_AS_23_24,
                                    data_indiv_rates_ES_23_24,
                                    data_indiv_rates_PP_23_24,
                                    data_indiv_rates_PK_23_24,]

all_situations_indiv_rates_23_24_update = [data_indiv_rates_AS_23_24_update,
                                           data_indiv_rates_ES_23_24_update,
                                           data_indiv_rates_PP_23_24_update,
                                           data_indiv_rates_PK_23_24_update,]

# INDIV ON-ICE TOTALS:
all_situations_on_ice_totals_23_24 = [data_on_ice_totals_AS_23_24,
                                      data_on_ice_totals_ES_23_24,
                                      data_on_ice_totals_PP_23_24,
                                      data_on_ice_totals_PK_23_24]

all_situations_on_ice_totals_23_24_update = [data_on_ice_totals_AS_23_24_update,
                                             data_on_ice_totals_ES_23_24_update,
                                             data_on_ice_totals_PP_23_24_update,
                                             data_on_ice_totals_PK_23_24_update,]


#INDIV ON-ICE RATES:
all_situations_on_ice_rates_23_24 = [data_on_ice_rates_AS_23_24,
                                     data_on_ice_rates_ES_23_24,
                                     data_on_ice_rates_PP_23_24,
                                     data_on_ice_rates_PK_23_24,]

all_situations_on_ice_rates_23_24_update = [data_on_ice_rates_AS_23_24_update,
                                            data_on_ice_rates_ES_23_24_update,
                                            data_on_ice_rates_PP_23_24_update,
                                            data_on_ice_rates_PK_23_24_update,]

# %%
# Import the functions from the EDA_functions.py page:
from EDA_functions import calculate_playing_age, concat_similar_dfs

# %% [markdown]
# ## BIO DATA EDA and EARLY FEATURE SELECTION AND FEATURE ENGINEERING:

# %%
# Found out some of the players in the 2023-2024 season have missing DOB data.
# Its possible they didn't play yet but were called up since this season's data is incomplete
# Since this season is still being played.

missing_DOB = data_BIOS_AS_23_24.loc[data_BIOS_AS_23_24['Date of Birth'] == '-']
indexes_to_drop = missing_DOB.index

for i in range(len(all_situations_bios_23_24)):
    all_situations_bios_23_24[i].drop(indexes_to_drop, inplace=True)

# %%
missing_DOB = data_BIOS_AS_23_24_update.loc[data_BIOS_AS_23_24_update['Date of Birth'] == '-']
missing_DOB
indexes_to_drop = missing_DOB.index

for i in range(len(all_situations_bios_23_24_update)):
    all_situations_bios_23_24_update[i].drop(indexes_to_drop, inplace=True)

# %%
# #Unnecessary columns in player bio dataframes:
# drop_columns_bio_dfs_23_24 = ['Date of Birth','Birth City',
#                               'Birth State/Province','Birth Country',
#                               'Nationality','Draft Year','Draft Team',
#                               'Draft Round','Round Pick','Overall Draft Position',]

# #Columns to keep in the player bio dataframes:
# keep_columns_bio_dfs_23_24 = ['Player', 'Team',
#                               'Position', 'Age',
#                               'Height (in)', 'Weight (lbs)',]

# season_year = 2024  # Use the actual current year
# age_col_name = 'Age'
# dob_col_name = 'Date of Birth'  # Replace with the actual column name if different

# # Early Feature ENgineering and Feature Selection for Bio Dataframes
# for i in range(len(all_situations_bios_23_24)):
#     all_situations_bios_23_24[i] = calculate_playing_age(all_situations_bios_23_24[i],
#                                                        dob_col_name,
#                                                        age_col_name,
#                                                        season_year)
#     all_situations_bios_23_24[i].drop(columns= drop_columns_bio_dfs_23_24, inplace=True)
#     all_situations_bios_23_24[i] = all_situations_bios_23_24[i].sort_index()
    
# df_bios_AS_23_24 = all_situations_bios_23_24[0] # 892 players
# df_bios_ES_23_24 = all_situations_bios_23_24[1] # 892 players
# df_bios_PP_23_24 = all_situations_bios_23_24[2] # 892 players
# df_bios_PK_23_24 = all_situations_bios_23_24[3] # 892 players

# %%
# Repeating for the UPDATE data frames: UPDATE!!!!
#Unnecessary columns in player bio dataframes:
drop_columns_bio_dfs_23_24 = ['Date of Birth','Birth City',
                              'Birth State/Province','Birth Country',
                              'Nationality','Draft Year','Draft Team',
                              'Draft Round','Round Pick','Overall Draft Position',]

#Columns to keep in the player bio dataframes:
keep_columns_bio_dfs_23_24 = ['Player', 'Team',
                              'Position', 'Age',
                              'Height (in)', 'Weight (lbs)',]

season_year = 2024  # Use the actual current year
age_col_name = 'Age'
dob_col_name = 'Date of Birth'  # Replace with the actual column name if different

# Early Feature ENgineering and Feature Selection for Bio Dataframes
for i in range(len(all_situations_bios_23_24_update)):
    all_situations_bios_23_24_update[i] = calculate_playing_age(all_situations_bios_23_24_update[i],
                                                       dob_col_name,
                                                       age_col_name,
                                                       season_year)
    all_situations_bios_23_24_update[i].drop(columns= drop_columns_bio_dfs_23_24, inplace=True)
    all_situations_bios_23_24_update[i] = all_situations_bios_23_24_update[i].sort_index()
    

df_bios_AS_23_24_update = all_situations_bios_23_24_update[0] 
df_bios_ES_23_24_update = all_situations_bios_23_24_update[1] 
df_bios_PP_23_24_update = all_situations_bios_23_24_update[2] 
df_bios_PK_23_24_update = all_situations_bios_23_24_update[3]

# %%
# # INDIVIDUAL SEASON TOTALS:
# for i in range(len(all_situations_indiv_totals_23_24)):
#     all_situations_indiv_totals_23_24[i].replace('-', 0, inplace=True)
#     all_situations_indiv_totals_23_24[i] = all_situations_indiv_totals_23_24[i].sort_index()

# df_indiv_totals_AS_23_24 = all_situations_indiv_totals_23_24[0] # 898 Players
# df_indiv_totals_ES_23_24 = all_situations_indiv_totals_23_24[1] # 898 Players
# df_indiv_totals_PP_23_24 = all_situations_indiv_totals_23_24[2] # 831 Players
# df_indiv_totals_PK_23_24 = all_situations_indiv_totals_23_24[3] # 783 Players

# %%
# INDIVIDUAL SEASON TOTALS: UPDATED!!!!
for i in range(len(all_situations_indiv_totals_23_24_update)):
    all_situations_indiv_totals_23_24_update[i].replace('-', 0, inplace=True)
    all_situations_indiv_totals_23_24_update[i] = all_situations_indiv_totals_23_24_update[i].sort_index()
# Saving the updated columns: 
df_indiv_totals_AS_23_24_update = all_situations_indiv_totals_23_24_update[0] 
df_indiv_totals_ES_23_24_update = all_situations_indiv_totals_23_24_update[1] 
df_indiv_totals_PP_23_24_update = all_situations_indiv_totals_23_24_update[2] 
df_indiv_totals_PK_23_24_update = all_situations_indiv_totals_23_24_update[3]

# %%
# # INDIVIDUAL SEASON RATES:
# for i in range(len(all_situations_indiv_rates_23_24)):
#     all_situations_indiv_rates_23_24[i].replace('-', 0, inplace=True)
#     all_situations_indiv_rates_23_24[i] = all_situations_indiv_rates_23_24[i].sort_index()

# df_indiv_rates_AS_23_24 = all_situations_indiv_rates_23_24[0]
# df_indiv_rates_ES_23_24 = all_situations_indiv_rates_23_24[1]
# df_indiv_rates_PP_23_24 = all_situations_indiv_rates_23_24[2]
# df_indiv_rates_PK_23_24 = all_situations_indiv_rates_23_24[3]

# %%
# INDIVIDUAL SEASON RATES: UPDATED!!!
for i in range(len(all_situations_indiv_rates_23_24_update)):
    all_situations_indiv_rates_23_24_update[i].replace('-', 0, inplace=True)
    all_situations_indiv_rates_23_24_update[i] = all_situations_indiv_rates_23_24_update[i].sort_index()
# Saving variable as updated stats
df_indiv_rates_AS_23_24_update = all_situations_indiv_rates_23_24_update[0]
df_indiv_rates_ES_23_24_update = all_situations_indiv_rates_23_24_update[1]
df_indiv_rates_PP_23_24_update = all_situations_indiv_rates_23_24_update[2]
df_indiv_rates_PK_23_24_update = all_situations_indiv_rates_23_24_update[3]

# %%
# # ON-ICE TOTALS:
# for i in range(len(all_situations_on_ice_totals_23_24)):
#    all_situations_on_ice_totals_23_24[i].replace('-', 0, inplace=True)
#    all_situations_on_ice_totals_23_24[i] = all_situations_on_ice_totals_23_24[i].sort_index()

# df_on_ice_totals_AS_23_24 = all_situations_on_ice_totals_23_24[0]
# df_on_ice_totals_ES_23_24 = all_situations_on_ice_totals_23_24[1]
# df_on_ice_totals_PP_23_24 = all_situations_on_ice_totals_23_24[2]
# df_on_ice_totals_PK_23_24 = all_situations_on_ice_totals_23_24[3]

# %%
# ON-ICE TOTALS: UPDATE!!!
for i in range(len(all_situations_on_ice_totals_23_24_update)):
   all_situations_on_ice_totals_23_24_update[i].replace('-', 0, inplace=True)
   all_situations_on_ice_totals_23_24_update[i] = all_situations_on_ice_totals_23_24_update[i].sort_index()

# Saving Updated columns
df_on_ice_totals_AS_23_24_update = all_situations_on_ice_totals_23_24_update[0]
df_on_ice_totals_ES_23_24_update = all_situations_on_ice_totals_23_24_update[1]
df_on_ice_totals_PP_23_24_update = all_situations_on_ice_totals_23_24_update[2]
df_on_ice_totals_PK_23_24_update = all_situations_on_ice_totals_23_24_update[3]

# %%
# # ON-ICE-RATES:
# for i in range(len(all_situations_on_ice_rates_23_24)):
#    all_situations_on_ice_rates_23_24[i].replace('-', 0, inplace=True)
#    all_situations_on_ice_rates_23_24[i] = all_situations_on_ice_rates_23_24[i].sort_index()

# df_on_ice_rates_AS_23_24 = all_situations_on_ice_rates_23_24[0]
# df_on_ice_rates_ES_23_24 = all_situations_on_ice_rates_23_24[1]
# df_on_ice_rates_PP_23_24 = all_situations_on_ice_rates_23_24[2]
# df_on_ice_rates_PK_23_24 = all_situations_on_ice_rates_23_24[3]

# %%
# ON-ICE-RATES: UPDATE !!!!
for i in range(len(all_situations_on_ice_rates_23_24_update)):
   all_situations_on_ice_rates_23_24_update[i].replace('-', 0, inplace=True)
   all_situations_on_ice_rates_23_24_update[i] = all_situations_on_ice_rates_23_24_update[i].sort_index()

df_on_ice_rates_AS_23_24_update = all_situations_on_ice_rates_23_24_update[0]
df_on_ice_rates_ES_23_24_update = all_situations_on_ice_rates_23_24_update[1]
df_on_ice_rates_PP_23_24_update = all_situations_on_ice_rates_23_24_update[2]
df_on_ice_rates_PK_23_24_update = all_situations_on_ice_rates_23_24_update[3]

# %% [markdown]
# ## Joining the dataframes to make the final player stats and bios for each game phase:

# %%
# # COMBINED BOTH TOTALS DATAFRAMES:
# all_situations_complete_TOTALS_23_24 = []
# for i in range(len(all_situations_indiv_totals_23_24)):
#     all_situations_complete_TOTALS_23_24.append(concat_similar_dfs(all_situations_indiv_totals_23_24[i],
#                                                   all_situations_on_ice_totals_23_24[i]))

# df_season_and_on_ice_TOTALS_AS_23_24 = all_situations_complete_TOTALS_23_24[0]
# df_season_and_on_ice_TOTALS_ES_23_24 = all_situations_complete_TOTALS_23_24[1]
# df_season_and_on_ice_TOTALS_PP_23_24 = all_situations_complete_TOTALS_23_24[2]
# df_season_and_on_ice_TOTALS_PK_23_24 = all_situations_complete_TOTALS_23_24[3]

# %%
# COMBINED BOTH TOTALS DATAFRAMES: UPDATE!!!!
all_situations_complete_TOTALS_23_24_update = []
for i in range(len(all_situations_indiv_totals_23_24_update)):
    all_situations_complete_TOTALS_23_24_update.append(concat_similar_dfs(all_situations_indiv_totals_23_24_update[i],
                                                  all_situations_on_ice_totals_23_24_update[i]))

df_season_and_on_ice_TOTALS_AS_23_24_update = all_situations_complete_TOTALS_23_24_update[0]
df_season_and_on_ice_TOTALS_ES_23_24_update = all_situations_complete_TOTALS_23_24_update[1]
df_season_and_on_ice_TOTALS_PP_23_24_update = all_situations_complete_TOTALS_23_24_update[2]
df_season_and_on_ice_TOTALS_PK_23_24_update = all_situations_complete_TOTALS_23_24_update[3]

# %%
# # COMBINED BOTH RATES DATAFRAMES:
# all_situations_complete_RATES_23_24 = []
# for i in range(len(all_situations_indiv_rates_23_24)):
#     all_situations_complete_RATES_23_24.append(concat_similar_dfs(all_situations_indiv_rates_23_24[i],
#                                                                   all_situations_on_ice_rates_23_24[i]))

# df_season_and_on_ice_RATES_AS_23_24 = all_situations_complete_RATES_23_24[0]
# df_season_and_on_ice_RATES_ES_23_24 = all_situations_complete_RATES_23_24[1]
# df_season_and_on_ice_RATES_PP_23_24 = all_situations_complete_RATES_23_24[2]
# df_season_and_on_ice_RATES_PK_23_24 = all_situations_complete_RATES_23_24[3]

# %%
# COMBINED BOTH RATES DATAFRAMES: UPDATE !!!!
all_situations_complete_RATES_23_24_update = []
for i in range(len(all_situations_indiv_rates_23_24_update)):
    all_situations_complete_RATES_23_24_update.append(concat_similar_dfs(all_situations_indiv_rates_23_24_update[i],
                                                                  all_situations_on_ice_rates_23_24_update[i]))

df_season_and_on_ice_RATES_AS_23_24_update = all_situations_complete_RATES_23_24_update[0]
df_season_and_on_ice_RATES_ES_23_24_update = all_situations_complete_RATES_23_24_update[1]
df_season_and_on_ice_RATES_PP_23_24_update = all_situations_complete_RATES_23_24_update[2]
df_season_and_on_ice_RATES_PK_23_24_update = all_situations_complete_RATES_23_24_update[3]

# %%
# # Combining the TOTALS and RATES dataframes:
# all_situations_complete_player_stats_23_24 = []
# for i in range(len(all_situations_indiv_totals_23_24)):
#    all_situations_complete_player_stats_23_24.append(concat_similar_dfs(all_situations_complete_TOTALS_23_24[i],
#                                                                         all_situations_complete_RATES_23_24[i])) 

# player_stats_no_bio_AS_23_24 = all_situations_complete_player_stats_23_24[0]
# player_stats_no_bio_ES_23_24 = all_situations_complete_player_stats_23_24[1]
# player_stats_no_bio_PP_23_24 = all_situations_complete_player_stats_23_24[2]
# player_stats_no_bio_PK_23_24 = all_situations_complete_player_stats_23_24[3]

# %%
# Combining the TOTALS and RATES dataframes: UPDATE!!!
all_situations_complete_player_stats_23_24_update = []
for i in range(len(all_situations_indiv_totals_23_24_update)):
   all_situations_complete_player_stats_23_24_update.append(concat_similar_dfs(all_situations_complete_TOTALS_23_24_update[i],
                                                                        all_situations_complete_RATES_23_24_update[i])) 

player_stats_no_bio_AS_23_24_update = all_situations_complete_player_stats_23_24_update[0]
player_stats_no_bio_ES_23_24_update = all_situations_complete_player_stats_23_24_update[1]
player_stats_no_bio_PP_23_24_update = all_situations_complete_player_stats_23_24_update[2]
player_stats_no_bio_PK_23_24_update = all_situations_complete_player_stats_23_24_update[3]

# %% [markdown]
# ### MERGING THE BIO AND GAME STATS DATAFRAMES:

# %%
def merge_similar_dfs(df1, df2, merge_col, how):
    """
    Merges two pandas DataFrames with similar columns by a specified column.
    
    This function identifies duplicate columns between two DataFrames and merges them on a specified column. 
    Duplicate columns, except for the merging column, are dropped from the second DataFrame to prevent 
    column duplication in the merged DataFrame. The resulting DataFrame will have its index reset to start at 1.

    Parameters:
    - df1 (pandas.DataFrame): The first DataFrame to merge.
    - df2 (pandas.DataFrame): The second DataFrame to merge. Duplicate columns, except for the merge column, will be dropped.
    - merge_col (str): The column name on which to merge the two DataFrames.
    - how (str): How to perform the merge. Can be one of 'left', 'right', 'outer', 'inner'.

    Returns:
    - pandas.DataFrame: The merged DataFrame containing combined data from df1 and df2 with index starting at 1.

    Raises:
    - ValueError: If 'merge_col' is not present in either DataFrame.
    - ValueError: If 'how' is not one of the expected merge strategies ('left', 'right', 'outer', 'inner').
    """
    
    valid_merge_methods = ['left', 'right', 'outer', 'inner']
    
    if how not in valid_merge_methods:
        raise ValueError(f"The 'how' parameter must be one of the following: {valid_merge_methods}")
    
    if merge_col not in df1.columns or merge_col not in df2.columns:
        raise ValueError(f"The specified 'merge_col' must be present in both DataFrames")

    try:
        duplicated_columns = df1.columns.intersection(df2.columns)
        duplicated_columns_to_drop = duplicated_columns.drop(merge_col)
        df2_with_duplicated_cols_dropped = df2.drop(columns=duplicated_columns_to_drop)
        df_merged = pd.merge(df1, df2_with_duplicated_cols_dropped, on=merge_col, how=how) 

        # Reset the index to start at 1 instead of the default 0.
        df_merged.reset_index(drop=True, inplace=True)
        df_merged.index += 1
        
    except KeyError as e:
        raise KeyError(f"Merge failed due to a KeyError: {e}. Ensure 'merge_col' is a column in both DataFrames.") from e
    
    return df_merged

# %%
# all_situations_FULL_PLAYER_STATISTICS_23_24 = []
# for i in range(len(all_situations_bios_23_24)):
#     all_situations_FULL_PLAYER_STATISTICS_23_24.append(merge_similar_dfs(df1=all_situations_bios_23_24[i],
#                                                                          df2=all_situations_complete_player_stats_23_24[i],
#                                                                          merge_col='Player',
#                                                                          how='inner')
#                                                                          )

# master_list_AS_23_24 = all_situations_FULL_PLAYER_STATISTICS_23_24[0]
# master_list_ES_23_24 = all_situations_FULL_PLAYER_STATISTICS_23_24[1]
# master_list_PP_23_24 = all_situations_FULL_PLAYER_STATISTICS_23_24[2]
# master_list_PK_23_24 = all_situations_FULL_PLAYER_STATISTICS_23_24[3]

# %%
# MERGING UPDTED DFs: UPDATE !!!!
all_situations_FULL_PLAYER_STATISTICS_23_24_update = []
for i in range(len(all_situations_bios_23_24_update)):
    all_situations_FULL_PLAYER_STATISTICS_23_24_update.append(merge_similar_dfs(df1=all_situations_bios_23_24_update[i],
                                                                         df2=all_situations_complete_player_stats_23_24_update[i],
                                                                         merge_col='Player',
                                                                         how='inner')
                                                                         )

master_list_AS_23_24_update = all_situations_FULL_PLAYER_STATISTICS_23_24_update[0]
master_list_ES_23_24_update = all_situations_FULL_PLAYER_STATISTICS_23_24_update[1]
master_list_PP_23_24_update = all_situations_FULL_PLAYER_STATISTICS_23_24_update[2]
master_list_PK_23_24_update = all_situations_FULL_PLAYER_STATISTICS_23_24_update[3]

# %%
# master_list_AS_23_24.to_csv('player_stats_master_list_AS_23_24.csv', index=False)
# master_list_ES_23_24.to_csv('player_stats_master_list_ES_23_24.csv', index=False)
# master_list_PP_23_24.to_csv('player_stats_master_list_PP_23_24.csv', index=False)
# master_list_PK_23_24.to_csv('player_stats_master_list_PK_23_24.csv', index=False)

# %%
#UPDATED COLUMNS !!!!
master_list_AS_23_24_update.to_csv('player_stats_master_list_AS_23_24_update.csv', index=False)
master_list_ES_23_24_update.to_csv('player_stats_master_list_ES_23_24_update.csv', index=False)
master_list_PP_23_24_update.to_csv('player_stats_master_list_PP_23_24_update.csv', index=False)
master_list_PK_23_24_update.to_csv('player_stats_master_list_PK_23_24_update.csv', index=False)

# %%
# df_master_AS_23_24 = pd.read_csv('player_stats_master_list_AS_23_24.csv')
# df_master_AS_23_24.head(20)

# %%
# UPDATED COLUMNS !!!
df_master_AS_23_24_update = pd.read_csv('player_stats_master_list_AS_23_24_update.csv')
df_master_AS_23_24_update.head(20)
# Out:
#                  Player      Team Position  Age  Height (in)  Weight (lbs)  \
# 0            Ryan Suter       DAL        D   39           73           205
# 1           Jeff Carter       PIT        C   39           75           219
# 2           Zach Parise       COL        L   40           71           195
# 3           Brent Burns       CAR        D   39           77           230
# 4           Corey Perry  CHI, EDM        R   39           75           208
# 5          Joe Pavelski       DAL        C   40           71           200
# 6         Mark Giordano       TOR        D   41           72           205
# 7         Alex Ovechkin       WSH        L   39           75           238
# 8         Evgeni Malkin       PIT        C   38           75           195
# 9         Blake Wheeler       NYR        R   38           77           220
# 10       Alex Goligoski       MIN        D   39           71           173
# ...
